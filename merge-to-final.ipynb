# %%
import pandas as pd
import os

# %%
# Define the directory containing the CSV files
folder_path = 'dataset/product_reviews_predicted'

# %%
# Initialize an empty list to hold dataframes
df_list = []

# %%
# Loop through all files in the folder
for file_name in os.listdir(folder_path):
    # Check if the file is a CSV
    if file_name.endswith('.csv'):
        # Extract product name from file name
        product_name = os.path.splitext(file_name)[0]
        
        # Create the full file path
        file_path = os.path.join(folder_path, file_name)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Add product name as a new column
        df['Product'] = product_name
        
        # Append the DataFrame to the list
        df_list.append(df)

# %%
# Concatenate all DataFrames in the list into a single DataFrame
final_df = pd.concat(df_list, ignore_index=True)

# %%
final_df
# Out:
#        Unnamed: 0            Username  Rating         Posted At  \
# 0               0             h*****a       5  2021-10-26 10:34
# 1               1           ngocshina       5  2022-04-26 16:29
# 2               2             t*****9       5  2022-02-16 21:19
# 3               3         hong_minh79       5  2023-02-14 22:21
# 4               4   trangtranggggg144       5  2021-10-22 09:32
# ...           ...                 ...     ...               ...
# 41442         313             n*****1       4  2023-05-24 08:27
# 41443         314              usadan       4  2022-05-17 21:00
# 41444         315             c*****a       3  2022-05-09 18:47
# 41445         316             n*****m       3  2022-05-13 12:59
# 41446         318  nguyenphuongvi1611       1  2022-05-19 10:25
#
#       Product Categories                                        Review Text  \
# 0                    NaN  Hàng giao đúng như trong mô tả, đóng gói đẹp, ...
# 1                    NaN  Chưa dùng nên chưa biết hiệu quả. Giao hàng nh...
# 2                    NaN  Sản phẩm giao hàng rất nhanh, chất lượng tốt c...
# 3                    NaN  Công dụng: giải rượu\nMình đã mua lần 2. Uống ...
# 4                    NaN  Hàng ok, đóng gói cẩm thận k bị vỡ. Chất lượng...
# ...                  ...                                                ...
# 41442                NaN  Mùi hương: tra xanh\nPhù hợp với loại da: mọi ...
# 41443                NaN  Ta nói đặt hàng chủ yếu để lấy cái gối hello k...
# 41444                NaN  Công dụng: xịt khử mùi\nMùi hương: ko giốn...
# 41445                NaN  Công dụng: xịt khử mùi\nMùi hương: trà xanh\nP...
# 41446                NaN  Công dụng: KHử mùi cơ thể\nMùi hương: trà xanh...
#
#                                          Shop's response  Likes  Page  Class  \
# 0                                                    NaN      0     1    0.0
# 1                                                    NaN      0     1    0.0
# 2                                                    NaN      0     1    1.0
# 3      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     1    0.0
# 4                                                    NaN      0     1    0.0
# ...                                                  ...    ...   ...    ...
# 41442                                                NaN      0     1    NaN
# 41443                                                NaN      0     2    NaN
# 41444                                                NaN      1     1    NaN
# 41445                                                NaN      1     1    NaN
# 41446                                                NaN      0     1    NaN
#
#        Probability                                            Product
# 0         0.000003  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 1         0.000009  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 2         1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 3         0.087927  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 4         0.525038  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# ...            ...                                                ...
# 41442          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41443          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41444          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41445          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41446          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
#
# [41447 rows x 12 columns]

# %%
# Save the final DataFrame to a new CSV file
final_df.to_csv('dataset/final.csv', index=False)

# Display the first few rows of the final DataFrame
final_df.head()
# Out:
#    Unnamed: 0           Username  Rating         Posted At Product Categories  \
# 0           0            h*****a       5  2021-10-26 10:34                NaN
# 1           1          ngocshina       5  2022-04-26 16:29                NaN
# 2           2            t*****9       5  2022-02-16 21:19                NaN
# 3           3        hong_minh79       5  2023-02-14 22:21                NaN
# 4           4  trangtranggggg144       5  2021-10-22 09:32                NaN
#
#                                          Review Text  \
# 0  Hàng giao đúng như trong mô tả, đóng gói đẹp, ...
# 1  Chưa dùng nên chưa biết hiệu quả. Giao hàng nh...
# 2  Sản phẩm giao hàng rất nhanh, chất lượng tốt c...
# 3  Công dụng: giải rượu\nMình đã mua lần 2. Uống ...
# 4  Hàng ok, đóng gói cẩm thận k bị vỡ. Chất lượng...
#
#                                      Shop's response  Likes  Page  Class  \
# 0                                                NaN      0     1    0.0
# 1                                                NaN      0     1    0.0
# 2                                                NaN      0     1    1.0
# 3  Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     1    0.0
# 4                                                NaN      0     1    0.0
#
#    Probability                                            Product
# 0     0.000003  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 1     0.000009  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 2     1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 3     0.087927  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 4     0.525038  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
