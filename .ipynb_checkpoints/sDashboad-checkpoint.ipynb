# %%
import pandas as pd
import numpy as np
import panel as pn

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e80e8b7a-12cf-4301-bb3f-5e91bed05f90" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8fa52b1b-d850-47be-9210-bb3ef73c2473":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"e4c97f6778a14bd3a59fff3f0e857d61","client_comm_id":"d0ee71328b354fcba8c6dd91a821f4cc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"8fa52b1b-d850-47be-9210-bb3ef73c2473","roots":{"p1002":"e80e8b7a-12cf-4301-bb3f-5e91bed05f90"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
df = pd.read_csv(r'dataset\final-ecommerce-review-crawled.csv')

# %%
df.head(7)
# Out:
#    Unnamed: 0           Username  Rating         Posted At Product Categories  \
# 0           0            h*****a       5  2021-10-26 10:34                NaN
# 1           1          ngocshina       5  2022-04-26 16:29                NaN
# 2           2            t*****9       5  2022-02-16 21:19                NaN
# 3           3        hong_minh79       5  2023-02-14 22:21                NaN
# 4           4  trangtranggggg144       5  2021-10-22 09:32                NaN
# 5           5      thanhluan8688       5  2022-05-04 20:22                NaN
# 6           6          getcaimat       5  2023-04-03 20:17                NaN
#
#                                          Review Text  \
# 0  Hàng giao đúng như trong mô tả, đóng gói đẹp, ...
# 1  Chưa dùng nên chưa biết hiệu quả. Giao hàng nh...
# 2  Sản phẩm giao hàng rất nhanh, chất lượng tốt c...
# 3  Công dụng: giải rượu\nMình đã mua lần 2. Uống ...
# 4  Hàng ok, đóng gói cẩm thận k bị vỡ. Chất lượng...
# 5  Đã mua lần 2, công dụng giải rượu rất tốt\nSẽ ...
# 6  Đối tượng sử dụng: người lớn\nCông dụng: giải ...
#
#                                      Shop's response  Likes  Page  Class  \
# 0                                                NaN      0     1    0.0
# 1                                                NaN      0     1    0.0
# 2                                                NaN      0     1    1.0
# 3  Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     1    0.0
# 4                                                NaN      0     1    0.0
# 5                                                NaN      0     1    1.0
# 6                                                NaN      0     2    1.0
#
#    Probability
# 0     0.000003
# 1     0.000009
# 2     1.000000
# 3     0.087927
# 4     0.525038
# 5     1.000000
# 6     0.999985

# %%
# Drop rows where 'Class' column has NaN values
df = df.dropna(subset=['Class'])

df.isna().sum()
# Out:
# Unnamed: 0                0
# Username                  0
# Rating                    0
# Posted At                 0
# Product Categories    28317
# Review Text               0
# Shop's response       26773
# Likes                     0
# Page                      0
# Class                     0
# Probability               0
# dtype: int64

# %%
from math import pi
from bokeh.palettes import Category20c, Category20
from bokeh.plotting import figure
from bokeh.transform import cumsum
pn.extension()

import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='19f8cb5b-afe0-4ee9-9f33-739642ebf02b'>
#   <div id="b697c403-1949-4275-95fb-267fa1d69751" data-root-id="19f8cb5b-afe0-4ee9-9f33-739642ebf02b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"da7db153-2887-4d4c-a34f-7880a0f4d42b":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"19f8cb5b-afe0-4ee9-9f33-739642ebf02b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d1581c92-bd5d-4277-ae59-3fbd98a49bb0","attributes":{"plot_id":"19f8cb5b-afe0-4ee9-9f33-739642ebf02b","comm_id":"f50f0030dfba40b6a90fba452b1119c5","client_comm_id":"43668d29926341869ea2bd7bfc87e2da"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"da7db153-2887-4d4c-a34f-7880a0f4d42b","roots":{"19f8cb5b-afe0-4ee9-9f33-739642ebf02b":"b697c403-1949-4275-95fb-267fa1d69751"},"root_ids":["19f8cb5b-afe0-4ee9-9f33-739642ebf02b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#create arry for pie chart
rate_df = df['Rating']
rate_df = rate_df.sort_values()
rate_df
# Out:
# 6208     4
# 6219     4
# 6220     4
# 6221     4
# 6222     4
#         ..
# 13950    5
# 13951    5
# 13952    5
# 13954    5
# 41436    5
# Name: Rating, Length: 38749, dtype: int64

# %%
rate_array = rate_df.to_numpy()
print(rate_array)
# Out:
# [4 4 4 ... 5 5 5]

# %%
# rate_count_01 = {i:rate_array.count(i) for i in rate_array}
# print(rate_count_01)
from collections import Counter

rate_count_01 = Counter(rate_array)

rate_count_01
# Out:
# Counter({5: 38549, 4: 200})

# %%
# rate_count_01 = {i:rate_array.count(i) for i in rate_array}
# print(rate_count_01)
from collections import Counter

rate_count_01 = Counter(rate_array)

rate_count_01
# Out:
# Counter({5: 38549, 4: 200})

# %%
len(rate_count_01)
# Out:
# 2

# %%
data_rate = pd.Series(rate_count_01).reset_index(name='value').rename(columns={'index':'rating'})
data_rate['angle'] = data_rate['value']/data_rate['value'].sum() * 2*pi
data_rate['color'] = Category20c[len(rate_count_01)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 data_rate = pd.Series(rate_count_01).reset_index(name='value').rename(columns={'index':'rating'})
#       2 data_rate['angle'] = data_rate['value']/data_rate['value'].sum() * 2*pi
# ----> 3 data_rate['color'] = Category20c[len(rate_count_01)]
#       5 # Assign colors, ensuring the length matches a Category20 palette length
#       6 if len(rate_count_01) <= 2:
#
# KeyError: 2

# %%
data_rate['angle']
# Out:
# 0    0.032430
# 1    6.250755
# Name: angle, dtype: float64

# %%
p_rate = figure(height=350, title="Pie Chart Rating", toolbar_location=None,
           tools="hover", tooltips="@rating start rate: @value", x_range=(-0.5, 1.0))

# %%
r_rate = p_rate.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='rating', source=data_rate)

# %%
p_rate.axis.axis_label=None
p_rate.axis.visible=False
p_rate.grid.grid_line_color = None

# %%
bokeh_pane = pn.pane.Bokeh(p_rate, theme="dark_minimal")

# %%
bokeh_pane
# Out:
# Bokeh(figure, theme='dark_minimal')

# %%
filtered_spam = df[df['Class'] == 1]
rating_counts_spam = filtered_spam['Rating'].value_counts().sort_index()
rating_counts_spam
# Out:
# 5    7
# Name: Rating, dtype: int64

# %%
bar_chart_spam = rating_counts_spam.hvplot(kind='bar', title='Quantity spam review', xlabel='Rating', ylabel='Quantity spam')
bar_chart_spam = pn.Column(bar_chart_spam)
bar_chart_spam
# Out:
# Column
#     [0] HoloViews(Bars)

# %%
filtered_normal = df[df['Class'] == 0]
rating_counts_normal = filtered_normal['Rating'].value_counts().sort_index()
rating_counts_normal
# Out:
# 5    27
# Name: Rating, dtype: int64

# %%
bar_chart_normal = rating_counts_normal.hvplot(kind='bar', title='Quantity normal review', xlabel='Rating', ylabel='Quantity normal')
bar_chart_normal = pn.Column(bar_chart_normal)
bar_chart_normal
# Out:
# Column
#     [0] HoloViews(Bars)

# %%
# Assuming the DataFrame is named 'df'
rating_counts = df['Rating'].value_counts().sort_index()

# Create a Markdown pane with the rating counts
rating_list = '\n'.join([f"Rating {rating}: {count} occurrences\n" for rating, count in rating_counts.items()])
rating_pane = pn.pane.Markdown(f"## Rating Counts\n{rating_list}")
rating_pane
# Out:
# Markdown(str)

# %%
# Create the FastListTemplate
template = pn.template.FastListTemplate(
    title='Report dashboard for products in shopee platforms',
    sidebar=[
        rating_pane,
    ],
    main=[
        pn.Row(pn.Column(bokeh_pane)),
        pn.Row(pn.Column(bar_chart_normal)),
        pn.Row(pn.Column(bar_chart_spam)),
    ],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

# %%
# template.show()
template.servable();
