# %%
import pandas as pd
import numpy as np
import panel as pn

import hvplot.pandas

# %%
df = pd.read_csv(r'dataset\final.csv')

# %%
a = df['Rating'].drop_duplicates()
a
# Out:
# 0       5
# 126     4
# 136     3
# 138     1
# 1241    2
# Name: Rating, dtype: int64

# %%
# df = pd.read_csv(r'dataset\tmdt.csv')

# %%
df.shape
# Out:
# (41447, 12)

# %%
df.tail(7)
# Out:
#        Unnamed: 0            Username  Rating         Posted At  \
# 41440         311         thaoxxxbgdr       4  2022-07-19 10:02
# 41441         312             t*****o       4  2022-08-23 15:56
# 41442         313             n*****1       4  2023-05-24 08:27
# 41443         314              usadan       4  2022-05-17 21:00
# 41444         315             c*****a       3  2022-05-09 18:47
# 41445         316             n*****m       3  2022-05-13 12:59
# 41446         318  nguyenphuongvi1611       1  2022-05-19 10:25
#
#       Product Categories                                        Review Text  \
# 41440                NaN  viết ở trên thì là được tặng son dưỡng nhưng n...
# 41441                NaN  Mùi hương dễ chịu ngăn mồ hôi kém chỉ được kho...
# 41442                NaN  Mùi hương: tra xanh\nPhù hợp với loại da: mọi ...
# 41443                NaN  Ta nói đặt hàng chủ yếu để lấy cái gối hello k...
# 41444                NaN  Công dụng: xịt khử mùi\nMùi hương: ko giốn...
# 41445                NaN  Công dụng: xịt khử mùi\nMùi hương: trà xanh\nP...
# 41446                NaN  Công dụng: KHử mùi cơ thể\nMùi hương: trà xanh...
#
#                                          Shop's response  Likes  Page  Class  \
# 41440  Rohto Mentholatum Viet Nam xin chào bạn, Rohto...      0     1    NaN
# 41441  Rohto Mentholatum Viet Nam xin chào bạn, Rohto...      0     1    NaN
# 41442                                                NaN      0     1    NaN
# 41443                                                NaN      0     2    NaN
# 41444                                                NaN      1     1    NaN
# 41445                                                NaN      1     1    NaN
# 41446                                                NaN      0     1    NaN
#
#        Probability                                            Product
# 41440          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41441          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41442          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41443          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41444          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41445          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41446          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...

# %%
df['Class'].isna().sum()
# Out:
# 0

# %%
df['Rating'].isna().sum()
# Out:
# 0

# %%
# Drop rows where 'Class' column has NaN values
df = df.dropna(subset=['Class'])

# %%
df['Class'].isna().sum()
# Out:
# 2698

# %%
df.shape
# Out:
# (41447, 12)

# %%
a = df['Rating']

# %%
a
# Out:
# 0       5
# 126     4
# 136     3
# 138     1
# 1241    2
# Name: Rating, dtype: int64

# %% [markdown]
# # pie chart

# %%
from math import pi
from bokeh.palettes import Category20c, Category20
from bokeh.plotting import figure
from bokeh.transform import cumsum
pn.extension()

import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0acaf646-363c-4ce9-9eca-8e4a2b867f94'>
#   <div id="fb134711-5a7d-4272-9c47-2a5dd56ada50" data-root-id="0acaf646-363c-4ce9-9eca-8e4a2b867f94" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d74c2747-fe93-4463-854f-6172b22dee3f":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0acaf646-363c-4ce9-9eca-8e4a2b867f94"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0a1a65be-a939-4904-a892-e787d822c917","attributes":{"plot_id":"0acaf646-363c-4ce9-9eca-8e4a2b867f94","comm_id":"7db5dc6e38e74a138b3aadf8b4868f8b","client_comm_id":"993710abcc3448ddba047f0bc18c5779"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"d74c2747-fe93-4463-854f-6172b22dee3f","roots":{"0acaf646-363c-4ce9-9eca-8e4a2b867f94":"fb134711-5a7d-4272-9c47-2a5dd56ada50"},"root_ids":["0acaf646-363c-4ce9-9eca-8e4a2b867f94"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#create arry for pie chart
rate_df = df['Rating']
rate_df = rate_df.sort_values()
rate_df
# Out:
# 41446    1
# 18203    1
# 18202    1
# 18201    1
# 18200    1
#         ..
# 14339    5
# 14340    5
# 14341    5
# 14334    5
# 20723    5
# Name: Rating, Length: 41447, dtype: int64

# %%
rate_array = rate_df.to_numpy()
print(rate_array)
# Out:
# [1 1 1 ... 5 5 5]

# %%
rate_array.shape
# Out:
# (41447,)

# %%
# rate_count_01 = {i:rate_array.count(i) for i in rate_array}
# print(rate_count_01)
from collections import Counter

rate_count_01 = Counter(rate_array)

rate_count_01
# Out:
# Counter({5: 38942, 4: 1472, 3: 512, 1: 314, 2: 207})

# %%
data_rate = pd.Series(rate_count_01).reset_index(name='value').rename(columns={'index':'rating'})
data_rate['angle'] = data_rate['value']/data_rate['value'].sum() * 2*pi
data_rate['color'] = Category20c[len(rate_count_01)]

# %%
p_rate = figure(height=350, title="Pie Chart Rating", toolbar_location=None,
           tools="hover", tooltips="@rating start rate: @value", x_range=(-0.5, 1.0))

# %%
r_rate = p_rate.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='rating', source=data_rate)

# %%
p_rate.axis.axis_label=None
p_rate.axis.visible=False
p_rate.grid.grid_line_color = None

# %%
bokeh_pane = pn.pane.Bokeh(p_rate, theme="dark_minimal")

# %%
bokeh_pane
# Out:
# Bokeh(figure, theme='dark_minimal')

# %% [markdown]
# # chart

# %% [markdown]
# # Barchart spam

# %%
filtered_spam = df[df['Class'] == 1]

# %%
filtered_spam
# Out:
#        Unnamed: 0              Username  Rating         Posted At  \
# 2               2               t*****9       5  2022-02-16 21:19
# 5               5         thanhluan8688       5  2022-05-04 20:22
# 6               6             getcaimat       5  2023-04-03 20:17
# 7               7  anhtuyet91_khoai.tay       5  2023-03-21 14:08
# 9               9       vothihonglyntpt       5  2023-02-28 12:58
# ...           ...                   ...     ...               ...
# 41427         147               l*****6       5  2022-05-12 12:28
# 41428         148          tranhang1706       5  2022-10-15 10:49
# 41430         150         chaudieuhuong       5  2022-05-19 11:41
# 41433         153            trucnl0101       5  2022-05-16 15:06
# 41435         155             vanbui257       5  2022-05-16 11:31
#
#       Product Categories                                        Review Text  \
# 2                    NaN  Sản phẩm giao hàng rất nhanh, chất lượng tốt c...
# 5                    NaN  Đã mua lần 2, công dụng giải rượu rất tốt\nSẽ ...
# 6                    NaN  Đối tượng sử dụng: người lớn\nCông dụng: giải ...
# 7                    NaN  Đối tượng sử dụng: loc gan\nCông dụng: giảm sa...
# 9                    NaN  Cái hộp đựng trang sức nó xinh xỉu luôn ak. Mà...
# ...                  ...                                                ...
# 41427                NaN  Mùi ko quá thơm đâu nên dùng làm xịt phòng thì...
# 41428                NaN  Mùi rất thích nhé, từ trước đến nay vẫn luôn d...
# 41430                NaN  Mình thấy quảng cáo là mua 2 chai xịt khử mùi ...
# 41433                NaN                                    Mùi hương: Thơm
# 41435                NaN                SP dùng rất thích. Tiếp tục ủng hộ.
#
#                                          Shop's response  Likes  Page  Class  \
# 2                                                    NaN      0     1    1.0
# 5                                                    NaN      0     1    1.0
# 6                                                    NaN      0     2    1.0
# 7      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     2    1.0
# 9      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     2    1.0
# ...                                                  ...    ...   ...    ...
# 41427                                                NaN      0    25    1.0
# 41428  Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0    25    1.0
# 41430                                                NaN      0    26    1.0
# 41433                                                NaN      0    26    1.0
# 41435                                                NaN      0    26    1.0
#
#        Probability                                            Product
# 2         1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 5         1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 6         0.999985  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 7         1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 9         0.999048  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# ...            ...                                                ...
# 41427     0.897634  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41428     0.998242  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41430     0.857221  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41433     0.980491  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41435     0.794515  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
#
# [12072 rows x 12 columns]

# %%
rating_counts_spam = filtered_spam['Rating'].value_counts().sort_index()

# %%
rating_counts_spam
# Out:
# Rating
# 4       46
# 5    12026
# Name: count, dtype: int64

# %%
bar_chart_spam = rating_counts_spam.hvplot(kind='bar', title='Quantity spam review', xlabel='Rating', ylabel='Quantity spam')

# %%
bar_chart_spam = pn.Column(bar_chart_spam)

# %%
bar_chart_spam
# Out:
# Column
#     [0] HoloViews(Bars, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# # Barchar normal

# %%
filtered_normal = df[df['Class'] == 0]

# %%
filtered_normal
# Out:
#        Unnamed: 0           Username  Rating         Posted At  \
# 0               0            h*****a       5  2021-10-26 10:34
# 1               1          ngocshina       5  2022-04-26 16:29
# 3               3        hong_minh79       5  2023-02-14 22:21
# 4               4  trangtranggggg144       5  2021-10-22 09:32
# 8               8            h*****3       5  2023-03-13 10:08
# ...           ...                ...     ...               ...
# 41429         149      duongthaolthb       5  2022-05-16 21:46
# 41431         151    vokimtaehyunggg       5  2022-10-30 16:39
# 41432         152       tngocminhthu       5  2022-05-22 16:10
# 41434         154         256nie89dc       5  2022-10-21 11:00
# 41436         156      ngockhue28804       5  2022-05-13 08:47
#
#       Product Categories                                        Review Text  \
# 0                    NaN  Hàng giao đúng như trong mô tả, đóng gói đẹp, ...
# 1                    NaN  Chưa dùng nên chưa biết hiệu quả. Giao hàng nh...
# 3                    NaN  Công dụng: giải rượu\nMình đã mua lần 2. Uống ...
# 4                    NaN  Hàng ok, đóng gói cẩm thận k bị vỡ. Chất lượng...
# 8                    NaN  Giao hàng thần tốc. Đặt t7, sáng t2 đã nhận đư...
# ...                  ...                                                ...
# 41429                NaN  Giao hàng nhanh đóng gói chắc chắn, chất lượng...
# 41431                NaN  Công dụng: xịt nách\nMùi hương: trà xanh\nPhù ...
# 41432                NaN  Thơm lắm nha, xịt lên mát lắm còn được tặng mó...
# 41434                NaN                                      Hàng đúng nha
# 41436                NaN                 Mùi hương: mk ko thích mùi này lắm
#
#                                          Shop's response  Likes  Page  Class  \
# 0                                                    NaN      0     1    0.0
# 1                                                    NaN      0     1    0.0
# 3      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     1    0.0
# 4                                                    NaN      0     1    0.0
# 8      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     2    0.0
# ...                                                  ...    ...   ...    ...
# 41429                                                NaN      0    25    0.0
# 41431  Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0    26    0.0
# 41432                                                NaN      0    26    0.0
# 41434  Rohto Mentholatum Viet Nam xin chào bạn, Rohto...      0    26    0.0
# 41436                                                NaN      0    27    0.0
#
#         Probability                                            Product
# 0      3.479280e-06  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 1      8.905387e-06  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 3      8.792746e-02  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 4      5.250382e-01  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 8      6.357373e-06  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# ...             ...                                                ...
# 41429  9.437426e-13  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41431  1.323094e-02  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41432  6.562089e-01  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41434  1.672671e-07  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41436  8.062616e-08  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
#
# [26677 rows x 12 columns]

# %%
rating_counts_normal = filtered_normal['Rating'].value_counts().sort_index()

# %%
rating_counts_normal
# Out:
# Rating
# 4      154
# 5    26523
# Name: count, dtype: int64

# %%
bar_chart_normal = rating_counts_normal.hvplot(kind='bar', title='Quantity normal review', xlabel='Rating', ylabel='Quantity normal')

# %%
bar_chart_normal = pn.Column(bar_chart_normal)

# %%
bar_chart_normal
# Out:
# Column
#     [0] HoloViews(Bars, height=300, sizing_mode='fixed', width=700)

# %% [markdown]
# # some calculator

# %%
df
# Out:
#        Unnamed: 0            Username  Rating         Posted At  \
# 0               0             h*****a       5  2021-10-26 10:34
# 1               1           ngocshina       5  2022-04-26 16:29
# 2               2             t*****9       5  2022-02-16 21:19
# 3               3         hong_minh79       5  2023-02-14 22:21
# 4               4   trangtranggggg144       5  2021-10-22 09:32
# ...           ...                 ...     ...               ...
# 41442         313             n*****1       4  2023-05-24 08:27
# 41443         314              usadan       4  2022-05-17 21:00
# 41444         315             c*****a       3  2022-05-09 18:47
# 41445         316             n*****m       3  2022-05-13 12:59
# 41446         318  nguyenphuongvi1611       1  2022-05-19 10:25
#
#       Product Categories                                        Review Text  \
# 0                    NaN  Hàng giao đúng như trong mô tả, đóng gói đẹp, ...
# 1                    NaN  Chưa dùng nên chưa biết hiệu quả. Giao hàng nh...
# 2                    NaN  Sản phẩm giao hàng rất nhanh, chất lượng tốt c...
# 3                    NaN  Công dụng: giải rượu\nMình đã mua lần 2. Uống ...
# 4                    NaN  Hàng ok, đóng gói cẩm thận k bị vỡ. Chất lượng...
# ...                  ...                                                ...
# 41442                NaN  Mùi hương: tra xanh\nPhù hợp với loại da: mọi ...
# 41443                NaN  Ta nói đặt hàng chủ yếu để lấy cái gối hello k...
# 41444                NaN  Công dụng: xịt khử mùi\nMùi hương: ko giốn...
# 41445                NaN  Công dụng: xịt khử mùi\nMùi hương: trà xanh\nP...
# 41446                NaN  Công dụng: KHử mùi cơ thể\nMùi hương: trà xanh...
#
#                                          Shop's response  Likes  Page  Class  \
# 0                                                    NaN      0     1    0.0
# 1                                                    NaN      0     1    0.0
# 2                                                    NaN      0     1    1.0
# 3      Rohto Mentholatum Việt Nam xin chào bạn, Rohto...      0     1    0.0
# 4                                                    NaN      0     1    0.0
# ...                                                  ...    ...   ...    ...
# 41442                                                NaN      0     1    NaN
# 41443                                                NaN      0     2    NaN
# 41444                                                NaN      1     1    NaN
# 41445                                                NaN      1     1    NaN
# 41446                                                NaN      0     1    NaN
#
#        Probability                                            Product
# 0         0.000003  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 1         0.000009  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 2         1.000000  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 3         0.087927  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# 4         0.525038  bạn-mới-nhập-coshbm--50-đơn-0đ-thực-phẩm-chức-...
# ...            ...                                                ...
# 41442          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41443          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41444          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41445          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
# 41446          NaN  xịt-khử-mùi-refre-x-hello-kitty-natural-green-...
#
# [41447 rows x 12 columns]

# %%
# Assuming the DataFrame is named 'df'
rating_counts = df['Rating'].value_counts().sort_index()

# Create a Markdown pane with the rating counts
rating_list = '\n'.join([f"Rating {rating}: {count} occurrences\n" for rating, count in rating_counts.items()])
rating_pane = pn.pane.Markdown(f"## Rating Counts\n{rating_list}")
rating_pane
# Out:
# Markdown(str)

# %%
# Filter the dataframe to include only rows with a rating of 5
df_5_star = df[df['Rating'] == 5]

# Group the data by product category and calculate the count of 5-star ratings
category_ratings = df_5_star.groupby('Product Categories')['Rating'].count()

# Get the product category with the highest count of 5-star ratings
best_category = category_ratings.idxmax()

# Get the count of 5-star ratings for the best category
best_category_count = category_ratings.max()

# Create a panel widget to display the best product category and its count
best_category_widget = pn.pane.Str("Best Product Category:")
best_category_widget.object += f"\nCategory: {best_category}"
best_category_widget.object += f"\nCount of 5-Star Ratings: {best_category_count}"

# %%
# # Filter the dataframe to include only rows with spam reviews (Class == 1)
# spam_reviews = df[df['Class'] == 1]

# # Group the data by product and calculate the count of spam reviews
# spam_counts = spam_reviews.groupby('Product Categories')['Class'].count()

# # Get the product with the most spam reviews
# product_with_most_spam = spam_counts.idxmax()

# # Get the count of spam reviews for the product with the most spam
# most_spam_count = spam_counts.max()

# print("Product with the most spam reviews:", product_with_most_spam)
# print("Number of spam reviews for the product:", most_spam_count)

# %%
# # Filter the dataframe to include only rows with spam reviews (Class == 1)
# spam_reviews = df[df['Class'] == 1]

# # Group the data by product and calculate the count of spam reviews
# spam_counts = spam_reviews.groupby('Product Categories')['Class'].count()

# # Get the product with the least spam reviews
# product_with_least_spam = spam_counts.idxmin()

# # Get the count of spam reviews for the product with the least spam
# least_spam_count = spam_counts.min()

# print("Product with the least spam reviews:", product_with_least_spam)
# print("Number of spam reviews for the product:", least_spam_count)

# %%
# Filter the dataframe to include only rows with spam reviews (Class == 1)
spam_reviews = df[df['Class'] == 1]

# Group the data by product and calculate the count of spam reviews
spam_counts = spam_reviews.groupby('Product Categories')['Class'].count()

# Get the product with the most spam reviews
product_with_most_spam = spam_counts.idxmax()

# Get the count of spam reviews for the product with the most spam
most_spam_count = spam_counts.max()

# Get the product with the least spam reviews
product_with_least_spam = spam_counts.idxmin()

# Get the count of spam reviews for the product with the least spam
least_spam_count = spam_counts.min()

# Create widgets for the sidebar
most_spam_widget = pn.widgets.StaticText(
    name="Product with the most spam reviews:",
    value=product_with_most_spam
)

most_spam_count_widget = pn.widgets.StaticText(
    name="Number of spam reviews for the product:",
    value=str(most_spam_count)
)

least_spam_widget = pn.widgets.StaticText(
    name="Product with the least spam reviews:",
    value=product_with_least_spam
)

least_spam_count_widget = pn.widgets.StaticText(
    name="Number of spam reviews for the product:",
    value=str(least_spam_count)
)

# %% [markdown]
# # Teamplate

# %%
# Create the FastListTemplate
template = pn.template.FastListTemplate(
    title='Report dashboard for products in shopee platforms',
    sidebar=[
        # rating_pane,
        # best_category_widget,
        # most_spam_widget,
        # most_spam_count_widget,
        # least_spam_widget,
        # least_spam_count_widget
    ],
    main=[
        # pn.Row(pn.Column(bokeh_pane)),
        # pn.Row(pn.Column(bar_chart_normal)),
        # pn.Row(pn.Column(bar_chart_spam)),
    ],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

# %%
# template.show()
template.servable();
